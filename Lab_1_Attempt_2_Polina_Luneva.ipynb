# %% [markdown]
# <a href="https://colab.research.google.com/github/lunevaaa/imc2023-luneva/blob/main/Lab_1_Attempt_2_Polina_Luneva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 86 (delta 36), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (86/86), 5.83 MiB | 3.82 MiB/s, done.

# %%
def readAudioFunction(audioFile, samplingRate):
    # remember that you only need to use plt.plot() once
  plt.plot(sig)
    # open the audio file avm.wav with librosa.load()
file = 'imc2023/audioFiles/avm2.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)
    # adjust the x-axis to represent time
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)
    # scale the y-axis to represent amplitude
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)
    # label the x and y axes
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
def readAudioFunction(audioFile, samplingRate):
    # remember that you only need to use plt.plot() once
  plt.plot(sig)
    # open the audio file avm2.wav with librosa.load()
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)
    # adjust the x-axis to represent time
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)
    # scale the y-axis to represent amplitude
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)
    # label the x and y axes
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
